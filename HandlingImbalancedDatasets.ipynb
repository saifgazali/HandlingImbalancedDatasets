# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Churn_Modelling.csv')

# %%
df = pd.read_csv('Churn_Modelling.csv')

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
X = data.iloc[:,3:-1]
Y = data.iloc[:,-1]

# %%
geog = data.iloc[:,4]

geog_arr = pd.get_dummies(geog,drop_first=True)

# %%
geog_arr
# Out:
#       Germany  Spain
# 0           0      0
# 1           0      1
# 2           0      0
# 3           0      0
# 4           0      1
# ...       ...    ...
# 9995        0      0
# 9996        0      0
# 9997        0      0
# 9998        1      0
# 9999        0      0
#
# [10000 rows x 2 columns]

# %%
gender = data.iloc[:,5]
gender_arr = pd.get_dummies(gender,drop_first=True)
gender_arr
# Out:
#       Male
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ...    ...
# 9995     1
# 9996     1
# 9997     0
# 9998     1
# 9999     0
#
# [10000 rows x 1 columns]

# %%
data.drop(labels=['Geography','Gender'],axis=1,inplace=True)

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore  Age  Tenure    Balance  \
# 0          1    15634602  Hargrave          619   42       2       0.00
# 1          2    15647311      Hill          608   41       1   83807.86
# 2          3    15619304      Onio          502   42       8  159660.80
# 3          4    15701354      Boni          699   39       1       0.00
# 4          5    15737888  Mitchell          850   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0

# %%
data = pd.concat((data,geog_arr,gender_arr),axis=1)

# %%
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore  Age  Tenure    Balance  \
# 0             1    15634602   Hargrave          619   42       2       0.00
# 1             2    15647311       Hill          608   41       1   83807.86
# 2             3    15619304       Onio          502   42       8  159660.80
# 3             4    15701354       Boni          699   39       1       0.00
# 4             5    15737888   Mitchell          850   43       2  125510.82
# ...         ...         ...        ...          ...  ...     ...        ...
# 9995       9996    15606229   Obijiaku          771   39       5       0.00
# 9996       9997    15569892  Johnstone          516   35      10   57369.61
# 9997       9998    15584532        Liu          709   36       7       0.00
# 9998       9999    15682355  Sabbatini          772   42       3   75075.31
# 9999      10000    15628319     Walker          792   28       4  130142.79
#
# ...

# %%
df = data.copy()

# %%
data.drop(['Exited'],axis=1,inplace=True)

# %%
X = data.iloc[:,3:]

# %%
X
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 0                  1        101348.88        0      0     0
# ...

# %%
print(Y)
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2)

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Dropout

# %%
ann = Sequential()

ann.add(Dense(units=128,kernel_initializer='he_uniform',activation='relu'))
ann.add(Dropout(rate=0.3))
ann.add(Dense(units=64,kernel_initializer='he_uniform',activation='relu'))
ann.add(Dropout(rate=0.3))
ann.add(Dense(units=32,kernel_initializer='he_uniform',activation='relu'))
ann.add(Dropout(rate=0.3))
ann.add(Dense(units=1,activation = 'sigmoid'))

# %%
ann.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
ann.fit(X_train,Y_train,batch_size=32,epochs=100)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 2s 2ms/step - loss: 8703.4521 - accuracy: 0.6808
# Epoch 2/100
# 250/250 [==============================] - 1s 2ms/step - loss: 380.3395 - accuracy: 0.6944
# Epoch 3/100
# 250/250 [==============================] - 1s 2ms/step - loss: 96.1624 - accuracy: 0.6988
# Epoch 4/100
# 250/250 [==============================] - 1s 3ms/step - loss: 43.6980 - accuracy: 0.7206
# Epoch 5/100
# 250/250 [==============================] - 1s 2ms/step - loss: 24.6103 - accuracy: 0.7537
# Epoch 6/100
# 250/250 [==============================] - 1s 2ms/step - loss: 20.6594 - accuracy: 0.7534
# Epoch 7/100
# 250/250 [==============================] - 0s 2ms/step - loss: 11.4183 - accuracy: 0.7560
# Epoch 8/100
# 250/250 [==============================] - 0s 2ms/step - loss: 8.3190 - accuracy: 0.7687
# Epoch 9/100
# 250/250 [==============================] - 0s 2ms/step - loss: 5.8573 - accuracy: 0.7754
# Epoch 10/100
# ...

# %%
ann.evaluate(X_test,Y_test)
# Out:
# 63/63 [==============================] - 0s 1ms/step - loss: 0.4944 - accuracy: 0.8045
# [0.49441152811050415, 0.8044999837875366]

# %%
y_pred = ann.predict(X_test) > 0.5

# %%
from sklearn.metrics import classification_report,confusion_matrix
cm = confusion_matrix(Y_test,y_pred)
print(cm)
# Out:
# [[1609    0]
#  [ 391    0]]

# %%
print(classification_report(Y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89      1609
#            1       0.00      0.00      0.00       391
#
#     accuracy                           0.80      2000
#    macro avg       0.40      0.50      0.45      2000
# weighted avg       0.65      0.80      0.72      2000
# C:\Users\saifgazali\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saifgazali\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
# f1-score is 0 for the customers who exited so basically we are not predicting properly for any customer who left .
# our model is as good as saying whatever customer comes he is going to stay.
# hence accuracy is misleading even though it is as high as 80%

# %% [markdown]
# ### Improving f1 score / Handling imbalance datasets

# %% [markdown]
# ### 1) Undersampling

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore  Age  Tenure    Balance  \
# 0          1    15634602  Hargrave          619   42       2       0.00
# 1          2    15647311      Hill          608   41       1   83807.86
# 2          3    15619304      Onio          502   42       8  159660.80
# 3          4    15701354      Boni          699   39       1       0.00
# 4          5    15737888  Mitchell          850   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  Germany  \
# 0              1          1               1        101348.88       1        0
# 1              1          0               1        112542.58       0        0
# 2              3          1               0        113931.57       1        0
# 3              2          0               0         93826.63       0        0
# 4              1          1               1         79084.10       0        0
#
#    Spain  Male
# 0      0     0
# 1      1     0
# ...

# %%
class_0_counts, class_1_counts = df.Exited.value_counts()

# %%
(class_0_counts, class_1_counts)
# Out:
# (7963, 2037)

# %%
df_class_0 = df[df['Exited'] == 0]
df_class_1 = df[df['Exited'] == 1]

# %%
df_class_0.shape
# Out:
# (7963, 15)

# %%
df_class_1.shape
# Out:
# (2037, 15)

# %%
## Undersampling
df_class_0.sample(2) # Randomly selects 2 sample
# Out:
#       RowNumber  CustomerId   Surname  CreditScore  Age  Tenure    Balance  \
# 7642       7643    15654760        Su          811   40       1  101514.89
# 7873       7874    15750441  Lavarack          782   36       5   81210.72
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 7642              1          1               1        121765.00       0
# 7873              2          0               1        108003.38       0
#
#       Germany  Spain  Male
# 7642        0      0     1
# 7873        0      0     1

# %%
df_class_0_under = df_class_0.sample(class_1_counts)
df_test_under = pd.concat((df_class_0_under,df_class_1),axis=0)

print(df_test_under.Exited.value_counts())
# Out:
# 1    2037
# 0    2037
# Name: Exited, dtype: int64

# %%
X = df_test_under.drop(['RowNumber','Exited','CustomerId','Surname'],axis=1)
Y = df_test_under['Exited']

# %%
X
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 7914          687   35       9       0.00              2          0
# 1874          529   35       5   95772.97              1          1
# 412           745   31       3  124328.84              1          1
# 507           684   40       6  137326.65              1          1
# 9242          612   32       9  106520.73              2          1
# ...           ...  ...     ...        ...            ...        ...
# 9981          498   42       3  152039.70              1          1
# 9982          655   46       7  137145.12              1          1
# 9991          597   53       4   88381.21              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 7914               1         73133.82        0      0     1
# ...

# %%
Y
# Out:
# 7914    0
# 1874    0
# 412     0
# 507     0
# 9242    0
#        ..
# 9981    1
# 9982    1
# 9991    1
# 9997    1
# 9998    1
# Name: Exited, Length: 4074, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,stratify=Y)

# %%
Y_train.value_counts() # almost equal number of 0 and 1 due to stratify set to y
# Out:
# 0    1630
# 1    1629
# Name: Exited, dtype: int64

# %%
ann = Sequential()

ann.add(Dense(units=128,kernel_initializer='he_uniform',activation='relu'))
ann.add(Dropout(rate=0.3))
ann.add(Dense(units=64,kernel_initializer='he_uniform',activation='relu'))
ann.add(Dropout(rate=0.3))
ann.add(Dense(units=32,kernel_initializer='he_uniform',activation='relu'))
ann.add(Dropout(rate=0.3))
ann.add(Dense(units=1,activation = 'sigmoid'))

# %%
ann.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
ann.fit(X_train,Y_train,batch_size=32,epochs=100)
# Out:
# Epoch 1/100
# 102/102 [==============================] - 1s 2ms/step - loss: 30846.0650 - accuracy: 0.5118
# Epoch 2/100
# 102/102 [==============================] - 0s 2ms/step - loss: 8007.0749 - accuracy: 0.5131
# Epoch 3/100
# 102/102 [==============================] - 0s 2ms/step - loss: 3849.7153 - accuracy: 0.5124
# Epoch 4/100
# 102/102 [==============================] - 0s 2ms/step - loss: 2701.3722 - accuracy: 0.4969
# Epoch 5/100
# 102/102 [==============================] - 0s 2ms/step - loss: 1624.9638 - accuracy: 0.4821
# Epoch 6/100
# 102/102 [==============================] - 0s 2ms/step - loss: 754.1128 - accuracy: 0.4950
# Epoch 7/100
# 102/102 [==============================] - 0s 2ms/step - loss: 448.5360 - accuracy: 0.5278
# Epoch 8/100
# 102/102 [==============================] - 0s 2ms/step - loss: 273.5295 - accuracy: 0.5084
# Epoch 9/100
# 102/102 [==============================] - 0s 2ms/step - loss: 206.3684 - accuracy: 0.5085
# Epoch 10/100
# ...

# %%
y_pred = ann.predict(X_test) > 0.9

# %%
from sklearn.metrics import classification_report,confusion_matrix
cm = confusion_matrix(Y_test,y_pred)
print(cm)
# Out:
# [[407   0]
#  [408   0]]

# %% [markdown]
# # Oversampling

# %%
(class_0_counts, class_1_counts)
# Out:
# (7963, 2037)

# %%
df_class_1
# Out:
#       RowNumber  CustomerId      Surname  CreditScore  Age  Tenure    Balance  \
# 0             1    15634602     Hargrave          619   42       2       0.00
# 2             3    15619304         Onio          502   42       8  159660.80
# 5             6    15574012          Chu          645   44       8  113755.78
# 7             8    15656148       Obinna          376   29       4  115046.74
# 16           17    15737452        Romeo          653   58       1  132602.88
# ...         ...         ...          ...          ...  ...     ...        ...
# 9981       9982    15672754     Burbidge          498   42       3  152039.70
# 9982       9983    15768163      Griffin          655   46       7  137145.12
# 9991       9992    15769959  Ajuluchukwu          597   53       4   88381.21
# 9997       9998    15584532          Liu          709   36       7       0.00
# 9998       9999    15682355    Sabbatini          772   42       3   75075.31
#
# ...

# %%
df_class_over = df_class_1.sample(class_0_counts,replace = True)

# %%
df_test_over = pd.concat((df_class_over,df_class_0),axis=0)

print(df_test_over.Exited.value_counts())
# Out:
# 1    7963
# 0    7963
# Name: Exited, dtype: int64

# %%
X = df_test_over.drop(['RowNumber','Exited','CustomerId','Surname'],axis=1)
Y = df_test_over['Exited']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,stratify=Y)

# %%
ann.fit(X_train,Y_train,batch_size=32,epochs=10)
# Out:
# Epoch 1/10
# 399/399 [==============================] - 1s 2ms/step - loss: 0.7547 - accuracy: 0.4968
# Epoch 2/10
# 399/399 [==============================] - 1s 2ms/step - loss: 0.7902 - accuracy: 0.5002
# Epoch 3/10
# 399/399 [==============================] - 1s 2ms/step - loss: 0.6937 - accuracy: 0.4994
# Epoch 4/10
# 399/399 [==============================] - 1s 2ms/step - loss: 0.6933 - accuracy: 0.4899
# Epoch 5/10
# 399/399 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.4976
# Epoch 6/10
# 399/399 [==============================] - 1s 2ms/step - loss: 0.6935 - accuracy: 0.4988
# Epoch 7/10
# 399/399 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.4952
# Epoch 8/10
# 399/399 [==============================] - 1s 2ms/step - loss: 0.7364 - accuracy: 0.4988
# Epoch 9/10
# 399/399 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.4976
# Epoch 10/10
# ...

# %% [markdown]
# ### SMOTE

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(sampling_strategy='minority')
X_sm,Y_sm = smote.fit_resample(X,Y)

# %%
Y_sm.value_counts()
# Out:
# 1    7963
# 0    7963
# Name: Exited, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,stratify=Y)

# %%
ann.fit(X_train,Y_train,batch_size=32,epochs=10)
# Out:
# Epoch 1/10
# 399/399 [==============================] - 1s 2ms/step - loss: 0.7274 - accuracy: 0.5017
# Epoch 2/10
# 399/399 [==============================] - 1s 2ms/step - loss: 0.6933 - accuracy: 0.4990
# Epoch 3/10
# 399/399 [==============================] - 1s 2ms/step - loss: 0.6937 - accuracy: 0.4999
# Epoch 4/10
# 399/399 [==============================] - 1s 2ms/step - loss: 0.6974 - accuracy: 0.4973
# Epoch 5/10
# 399/399 [==============================] - 1s 2ms/step - loss: 0.7418 - accuracy: 0.4991
# Epoch 6/10
# 399/399 [==============================] - 1s 2ms/step - loss: 0.8882 - accuracy: 0.4997
# Epoch 7/10
# 399/399 [==============================] - 1s 3ms/step - loss: 0.6931 - accuracy: 0.4946
# Epoch 8/10
# 399/399 [==============================] - 1s 2ms/step - loss: 0.7316 - accuracy: 0.4943
# Epoch 9/10
# 399/399 [==============================] - 1s 2ms/step - loss: 0.6932 - accuracy: 0.5008
# Epoch 10/10
# ...

# %% [markdown]
# ### Use of Ensemble with undersampling

# %%
from xgboost import XGBClassifier

# %%
model = XGBClassifier()

# %%
model.fit(X_train,Y_train)
# Out:
# C:\Users\saifgazali\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [00:02:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
# ...

# %%
model.score(X_test,Y_test)
# Out:
# 0.9033270558694287

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix
cm = confusion_matrix(Y_test,y_pred)
print(cm)
# Out:
# [[1387  206]
#  [ 102 1491]]

# %%
print(classification_report(Y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90      1593
#            1       0.88      0.94      0.91      1593
#
#     accuracy                           0.90      3186
#    macro avg       0.91      0.90      0.90      3186
# weighted avg       0.91      0.90      0.90      3186
